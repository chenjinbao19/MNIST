# %%
#导入必要的库
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
import torchvision.transforms as transforms

# %%
# 设定超参数
batch_size = 64
learning_rate = 0.001
num_epochs = 10

# %%
# 数据预处理
transform = transforms.Compose([
    transforms.ToTensor(),          # 将图像转化为张量
    transforms.Normalize((0.1307,), (0.3081,)) # 对图像进行归一化处理
])

# %%
# 加载数据集
train_data = MNIST(root='./data', train=True, download=True, transform=transform)
test_data = MNIST(root='./data', train=False, download=True, transform=transform)

# %%
# 创建DataLoader
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=True)

# %%
# 定义网络模型
class SimpleNet(nn.Module):
    def __init__(self):
        super(SimpleNet, self).__init__()
        self.fc = nn.Sequential(
            nn.Linear(28*28, 128),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Dropout(p=0.5),
            nn.Linear(64, 10)  # 输出层为10个分类
        )

    def forward(self, x):
        x = x.view(-1, 28*28)
        return self.fc(x)

model = SimpleNet()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
criterion = nn.CrossEntropyLoss()

# %%
# 训练过程
for epoch in range(num_epochs):
    model.train()
    for i, (images, labels) in enumerate(train_loader):
        outputs = model(images)
        loss = criterion(outputs, labels)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        if (i+1) % 100 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}], Loss: {loss.item():.4f}')

# 测试过程
with torch.no_grad():
    correct = 0
    total = 0
    model.eval()
    for images, labels in test_loader:
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    accuracy = 100 * correct / total
    print('Test Accuracy of the model on {} test images: {:.2f} %'.format(total, accuracy))
# Out:
# Epoch [1/10], Step [100], Loss: 0.7927
# Epoch [1/10], Step [200], Loss: 0.5853
# Epoch [1/10], Step [300], Loss: 0.6704
# Epoch [1/10], Step [400], Loss: 0.2987
# Epoch [1/10], Step [500], Loss: 0.3050
# Epoch [1/10], Step [600], Loss: 0.4666
# Epoch [1/10], Step [700], Loss: 0.4651
# Epoch [1/10], Step [800], Loss: 0.3782
# Epoch [1/10], Step [900], Loss: 0.4698
# Epoch [2/10], Step [100], Loss: 0.3279
# Epoch [2/10], Step [200], Loss: 0.1600
# Epoch [2/10], Step [300], Loss: 0.1242
# Epoch [2/10], Step [400], Loss: 0.2654
# Epoch [2/10], Step [500], Loss: 0.3670
# Epoch [2/10], Step [600], Loss: 0.2862
# Epoch [2/10], Step [700], Loss: 0.2958
# Epoch [2/10], Step [800], Loss: 0.2446
# Epoch [2/10], Step [900], Loss: 0.4469
# Epoch [3/10], Step [100], Loss: 0.1754
# Epoch [3/10], Step [200], Loss: 0.1586
# Epoch [3/10], Step [300], Loss: 0.1119
# Epoch [3/10], Step [400], Loss: 0.2658
# Epoch [3/10], Step [500], Loss: 0.2807
# Epoch [3/10], Step [600], Loss: 0.2507
# Epoch [3/10], Step [700], Loss: 0.3555
# Epoch [3/10], Step [800], Loss: 0.1719
# Epoch [3/10], Step [900], Loss: 0.5129
# Epoch [4/10], Step [100], Loss: 0.2364
# Epoch [4/10], Step [200], Loss: 0.3043
# Epoch [4/10], Step [300], Loss: 0.4147
# Epoch [4/10], Step [400], Loss: 0.3272
# Epoch [4/10], Step [500], Loss: 0.3750
# Epoch [4/10], Step [600], Loss: 0.1771
# Epoch [4/10], Step [700], Loss: 0.1725
# Epoch [4/10], Step [800], Loss: 0.2732
# Epoch [4/10], Step [900], Loss: 0.1790
# Epoch [5/10], Step [100], Loss: 0.3231
# Epoch [5/10], Step [200], Loss: 0.1413
# Epoch [5/10], Step [300], Loss: 0.1332
# Epoch [5/10], Step [400], Loss: 0.1996
# Epoch [5/10], Step [500], Loss: 0.3240
# Epoch [5/10], Step [600], Loss: 0.1551
# Epoch [5/10], Step [700], Loss: 0.2154
# Epoch [5/10], Step [800], Loss: 0.1519
# Epoch [5/10], Step [900], Loss: 0.2496
# Epoch [6/10], Step [100], Loss: 0.1798
# Epoch [6/10], Step [200], Loss: 0.2536
# Epoch [6/10], Step [300], Loss: 0.1990
# Epoch [6/10], Step [400], Loss: 0.3566
# Epoch [6/10], Step [500], Loss: 0.2512
# Epoch [6/10], Step [600], Loss: 0.3090
# Epoch [6/10], Step [700], Loss: 0.2767
# Epoch [6/10], Step [800], Loss: 0.0754
# Epoch [6/10], Step [900], Loss: 0.0908
# Epoch [7/10], Step [100], Loss: 0.1003
# Epoch [7/10], Step [200], Loss: 0.4294
# Epoch [7/10], Step [300], Loss: 0.1008
# Epoch [7/10], Step [400], Loss: 0.2742
# Epoch [7/10], Step [500], Loss: 0.1282
# Epoch [7/10], Step [600], Loss: 0.1929
# Epoch [7/10], Step [700], Loss: 0.0557
# Epoch [7/10], Step [800], Loss: 0.0714
# Epoch [7/10], Step [900], Loss: 0.0818
# Epoch [8/10], Step [100], Loss: 0.3482
# Epoch [8/10], Step [200], Loss: 0.2935
# Epoch [8/10], Step [300], Loss: 0.2088
# Epoch [8/10], Step [400], Loss: 0.0717
# Epoch [8/10], Step [500], Loss: 0.1084
# Epoch [8/10], Step [600], Loss: 0.3145
# Epoch [8/10], Step [700], Loss: 0.5076
# Epoch [8/10], Step [800], Loss: 0.1640
# Epoch [8/10], Step [900], Loss: 0.1959
# Epoch [9/10], Step [100], Loss: 0.1725
# Epoch [9/10], Step [200], Loss: 0.1288
# Epoch [9/10], Step [300], Loss: 0.1179
# Epoch [9/10], Step [400], Loss: 0.1626
# Epoch [9/10], Step [500], Loss: 0.1190
# Epoch [9/10], Step [600], Loss: 0.2497
# Epoch [9/10], Step [700], Loss: 0.6910
# Epoch [9/10], Step [800], Loss: 0.4260
# Epoch [9/10], Step [900], Loss: 0.0978
# Epoch [10/10], Step [100], Loss: 0.1702
# Epoch [10/10], Step [200], Loss: 0.1780
# Epoch [10/10], Step [300], Loss: 0.1658
# Epoch [10/10], Step [400], Loss: 0.2395
# Epoch [10/10], Step [500], Loss: 0.3683
# Epoch [10/10], Step [600], Loss: 0.1701
# Epoch [10/10], Step [700], Loss: 0.1533
# Epoch [10/10], Step [800], Loss: 0.3346
# Epoch [10/10], Step [900], Loss: 0.1943
# Test Accuracy of the model on 10000 test images: 97.11 %
